# %% [markdown]
# # Creating Clickstream Data
#
# Recommendations can be made more context aware and accurate by including user behavior like clicks. This notebook assumes you have fully deployed the Personalens project both as an application and the Personalize service in your AWS account.
#
# ## Getting Started
#
# Before running the rest of this notebook fill out the variables below:

# %%
# Obtain these from the DB Notebook
campaignArn = "arn:aws:personalize:us-east-1:059124553121:campaign/Dj-campaign"

# %%
# Imports
import boto3

import json
import numpy as np
import pandas as pd
import time

# !wget -N https://s3-us-west-2.amazonaws.com/personalize-cli-json-models/personalize.json
# !wget -N https://s3-us-west-2.amazonaws.com/personalize-cli-json-models/personalize-runtime.json
# !wget -N https://s3-us-west-2.amazonaws.com/personalize-cli-json-models/personalize-events.json
# !aws configure add-model --service-model file://`pwd`/personalize.json --service-name personalize
# !aws configure add-model --service-model file://`pwd`/personalize-runtime.json --service-name personalize-runtime
# !aws configure add-model --service-name personalize-events --service-model file://personalize-events.json

personalize = boto3.client(service_name='personalize', endpoint_url='https://personalize.us-east-1.amazonaws.com')
personalize_runtime = boto3.client(service_name='personalize-runtime', endpoint_url='https://personalize-runtime.us-east-1.amazonaws.com')
# Out:
# --2019-02-15 21:40:14--  https://s3-us-west-2.amazonaws.com/personalize-cli-json-models/personalize.json
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.245.216
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.245.216|:443... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘personalize.json’ not modified on server. Omitting download.
#
# --2019-02-15 21:40:15--  https://s3-us-west-2.amazonaws.com/personalize-cli-json-models/personalize-runtime.json
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.245.216
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.245.216|:443... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘personalize-runtime.json’ not modified on server. Omitting download.
#
# --2019-02-15 21:40:15--  https://s3-us-west-2.amazonaws.com/personalize-cli-json-models/personalize-events.json
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.245.216
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.245.216|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3940 (3.8K) [application/json]
# Saving to: ‘personalize-events.json’
#
# personalize-events. 100%[===================>]   3.85K  --.-KB/s    in 0s
#
# 2019-02-15 21:40:15 (195 MB/s) - ‘personalize-events.json’ saved [3940/3940]

# %%
# Imports for Django and Pandas

import json
import datetime
import django
django.setup()

from movielens.models import User
from movielens.models import Item
from movielens.models import UserData

from movielens.views import stream_event

# %% [markdown]
# ## Creating an IAM Role
#
# Follow the instructions here, then save the roleARN in the variable below.
#
# https://docs.aws.amazon.com/personalize/latest/dg/getting-started.html#gs-create-role-with-permissions

# %%
roleArn = "arn:aws:iam::059124553121:role/PersonalizeRole"

# %% [markdown]
# ## Set Dataset group for the clickstream data
#
# From your previous notebook `Personalize_Sample_With_DB.ipynb` obtain your `datasetGroupArn` and define it below.

# %%
personalize = boto3.client('personalize')

datasetGroupArn = "arn:aws:personalize:us-east-1:059124553121:dataset-group/personalens-dataset-group"

# %% [markdown]
# ## Getting a Tracking ID
#
# A tracking ID associates an event with a dataset group and authorizes you to send data to Amazon Personalize. You generate a tracking ID by calling the CreateEventTracker API. You supply the IAM role that you created in Create an IAM Role.

# %%
# Obtain the dataset group ARN from the previous output:
response = personalize.create_event_tracker(
    name="MovieClickTracker",
    datasetGroupArn=datasetGroupArn,
    roleArn=roleArn
)
print(response['eventTrackerArn'])
print(response['trackingId'])
# Out:
# arn:aws:personalize:us-east-1:059124553121:event-tracker/a2344bdf
# 4a7e200e-9de4-46ee-acb0-4494371d5670

# %%
# Save the Tracker ID and ARN:
eventTrackerArn = "arn:aws:personalize:us-east-1:059124553121:event-tracker/a2344bdf"
trackingId = "4a7e200e-9de4-46ee-acb0-4494371d5670"

# %% [markdown]
# The schema for the event data is already predefined, you can learn more here: https://docs.aws.amazon.com/personalize/latest/dg/recording-events.html
#
# The schema itself:
#
# ```JSON
# {
#     "schema": {
#         "name": "event-interactions-schema",
#         "schemaArn": "arn:aws:personalize:us-west-2:acct-id:schema/event-interactions-schema",
#         "schema": {
#           "type": "record",
#           "name": "Interactions",
#           "namespace": "com.amazonaws.personalize.schema",
#           "fields": [
#             {
#               "name": "user_id",
#               "type": "string"
#             },
#             {
#               "name": "session_id",
#               "type": "string"
#             },
#             {
#               "name": "timestamp",
#               "type": "long"
#             }
#             {
#               "name": "event_type",
#               "type": "string"
#             },
#             {
#               "name": "item_id",
#               "type": "string"
#             },
#             {
#               "name": "event_value",
#               "type": "string"
#             },
#           ],
#           "version": "1.0"
#         }"
#     }
# }
# ```

# %% [markdown]
# ## Patching Up Users
#
# When the users were first saved, a session ID was not specified for them, you can see that it is required above in the schema so we should generate and save something now. For simplistic purposes we will just set it to be equal to the users' primary key, however in a production system this could change with varying visits and could signal intent.

# %%
users = User.objects.all()
for user in users:
    user.session = user.user_id
    user.save()

# %% [markdown]
# ## Creating Seed Data
#
# Now with the datagroup able to receive events, you will need to supply a few initial items to get the dataset ready for the model training process. Below a collection of users will "click" on random movies and then stream that data into the dataset.

# %% [markdown]
# Before continuing take the trackingId from above and using Cloud9 save it to the settings.py file in the personalens sub folder.

# %%
import django
django.setup()

from movielens.models import User
from movielens.models import Item
from movielens.models import UserData

from movielens.views import stream_event

# %%
# First let us define the first 10 users that we are going to generate data for

users = User.objects.all()[:10]

# Now for each user we want them to click a collection of 100 random movies

for user in users:
    for x in range(0, 99):
        movie = Item.objects.order_by('?').first()
        stream_event(user=user, movie=movie)
# Out:
# Clickstream Status:  True
# Streaming event:  1 Robocop 3 (1993)
# Clickstream Status:  True
# Streaming event:  1 Next Step, The (1995)
# Clickstream Status:  True
# Streaming event:  1 Davy Crockett, King of the Wild Frontier (1955)
# Clickstream Status:  True
# Streaming event:  1 Dead Poets Society (1989)
# Clickstream Status:  True
# Streaming event:  1 NeverEnding Story III, The (1994)
# Clickstream Status:  True
# Streaming event:  1 Courage Under Fire (1996)
# Clickstream Status:  True
# Streaming event:  1 Maverick (1994)
# Clickstream Status:  True
# Streaming event:  1 Brady Bunch Movie, The (1995)
# Clickstream Status:  True
# Streaming event:  1 Blink (1994)
# Clickstream Status:  True
# Streaming event:  1 Phat Beach (1996)
# Clickstream Status:  True
# Streaming event:  1 Gold Diggers: The Secret of Bear Mountain (1995)
# Clickstream Status:  True
# Streaming event:  1 Red Corner (1997)
# Clickstream Status:  True
# Streaming event:  1 Murder, My Sweet (1944)
# Clickstream Status:  True
# Streaming event:  1 Fox and the Hound, The (1981)
# Clickstream Status:  True
# Streaming event:  1 Last Action Hero (1993)
# Clickstream Status:  True
# Streaming event:  1 Empire Strikes Back, The (1980)
# Clickstream Status:  True
# Streaming event:  1 Mark of Zorro, The (1940)
# Clickstream Status:  True
# Streaming event:  1 Anastasia (1997)
# Clickstream Status:  True
# Streaming event:  1 Day the Earth Stood Still, The (1951)
# Clickstream Status:  True
# Streaming event:  1 Sweet Hereafter, The (1997)
# Clickstream Status:  True
# Streaming event:  1 Malice (1993)
# Clickstream Status:  True
# Streaming event:  1 Mamma Roma (1962)
# Clickstream Status:  True
# Streaming event:  1 Boys of St. Vincent, The (1993)
# Clickstream Status:  True
# Streaming event:  1 Don't Be a Menace to South Central While Drinking Your Juice in the Hood (1996)
# Clickstream Status:  True
# Streaming event:  1 Prophecy II, The (1998)
# Clickstream Status:  True
# Streaming event:  1 Craft, The (1996)
# Clickstream Status:  True
# Streaming event:  1 Chairman of the Board (1998)
# Clickstream Status:  True
# Streaming event:  1 Beans of Egypt, Maine, The (1994)
# Clickstream Status:  True
# Streaming event:  1 Tombstone (1993)
# Clickstream Status:  True
# Streaming event:  1 Big Night (1996)
# Clickstream Status:  True
# Streaming event:  1 It Could Happen to You (1994)
# Clickstream Status:  True
# Streaming event:  1 Critical Care (1997)
# Clickstream Status:  True
# Streaming event:  1 Ice Storm, The (1997)
# Clickstream Status:  True
# Streaming event:  1 Indian in the Cupboard, The (1995)
# Clickstream Status:  True
# Streaming event:  1 Blue Chips (1994)
# Clickstream Status:  True
# Streaming event:  1 Lion King, The (1994)
# Clickstream Status:  True
# Streaming event:  1 Associate, The (1996)
# Clickstream Status:  True
# Streaming event:  1 Bloody Child, The (1996)
# Clickstream Status:  True
# Streaming event:  1 My Fellow Americans (1996)
# Clickstream Status:  True
# Streaming event:  1 Last Klezmer: Leopold Kozlowski, His Life and Music, The (1995)
# Clickstream Status:  True
# Streaming event:  1 Buddy (1997)
# Clickstream Status:  True
# Streaming event:  1 Celluloid Closet, The (1995)
# Clickstream Status:  True
# Streaming event:  1 Jungle2Jungle (1997)
# Clickstream Status:  True
# Streaming event:  1 Apartment, The (1960)
# Clickstream Status:  True
# Streaming event:  1 In the Company of Men (1997)
# Clickstream Status:  True
# Streaming event:  1 Celtic Pride (1996)
# Clickstream Status:  True
# Streaming event:  1 Ruby in Paradise (1993)
# Clickstream Status:  True
# Streaming event:  1 Dances with Wolves (1990)
# Clickstream Status:  True
# Streaming event:  1 Mondo (1996)
# Clickstream Status:  True
# Streaming event:  1 Top Gun (1986)
# Clickstream Status:  True
# Streaming event:  1 Breakdown (1997)
# Clickstream Status:  True
# Streaming event:  1 Disclosure (1994)
# Clickstream Status:  True
# Streaming event:  1 Shooter, The (1995)
# Clickstream Status:  True
# Streaming event:  1 Low Down Dirty Shame, A (1994)
# Clickstream Status:  True
# Streaming event:  1 Time Tracers (1995)
# Clickstream Status:  True
# Streaming event:  1 Someone Else's America (1995)
# Clickstream Status:  True
# Streaming event:  1 Pushing Hands (1992)
# Clickstream Status:  True
# Streaming event:  1 Stars Fell on Henrietta, The (1995)
# Clickstream Status:  True
# Streaming event:  1 Air Bud (1997)
# Clickstream Status:  True
# Streaming event:  1 Life Less Ordinary, A (1997)
# Clickstream Status:  True
# Streaming event:  1 To Die For (1995)
# Clickstream Status:  True
# Streaming event:  1 JLG/JLG - autoportrait de décembre (1994)
# Clickstream Status:  True
# Streaming event:  1 Murder at 1600 (1997)
# Clickstream Status:  True
# Streaming event:  1 Very Brady Sequel, A (1996)
# Clickstream Status:  True
# Streaming event:  1 Evening Star, The (1996)
# Clickstream Status:  True
# Streaming event:  1 Lay of the Land, The (1997)
# Clickstream Status:  True
# Streaming event:  1 Unzipped (1995)
# Clickstream Status:  True
# Streaming event:  1 Celestial Clockwork (1994)
# Clickstream Status:  True
# Streaming event:  1 Afterglow (1997)
# Clickstream Status:  True
# Streaming event:  1 Men in Black (1997)
# Clickstream Status:  True
# Streaming event:  1 Real Genius (1985)
# Clickstream Status:  True
# Streaming event:  1 Delicatessen (1991)
# Clickstream Status:  True
# Streaming event:  1 Marvin's Room (1996)
# Clickstream Status:  True
# Streaming event:  1 Last Time I Saw Paris, The (1954)
# Clickstream Status:  True
# Streaming event:  1 Carrie (1976)
# Clickstream Status:  True
# Streaming event:  1 Heat (1995)
# Clickstream Status:  True
# Streaming event:  1 Dead Man (1995)
# Clickstream Status:  True
# Streaming event:  1 Lamerica (1994)
# Clickstream Status:  True
# Streaming event:  1 Cronos (1992)
# Clickstream Status:  True
# Streaming event:  1 Ridicule (1996)
# Clickstream Status:  True
# Streaming event:  1 Sense and Sensibility (1995)
# Clickstream Status:  True
# Streaming event:  1 Bottle Rocket (1996)
# Clickstream Status:  True
# Streaming event:  1 To Have, or Not (1995)
# Clickstream Status:  True
# Streaming event:  1 Kazaam (1996)
# Clickstream Status:  True
# Streaming event:  1 Substance of Fire, The (1996)
# Clickstream Status:  True
# Streaming event:  1 City Hall (1996)
# Clickstream Status:  True
# Streaming event:  1 Fear (1996)
# Clickstream Status:  True
# Streaming event:  1 When We Were Kings (1996)
# Clickstream Status:  True
# Streaming event:  1 Return of the Jedi (1983)
# Clickstream Status:  True
# Streaming event:  1 Chairman of the Board (1998)
# Clickstream Status:  True
# Streaming event:  1 Brothers in Trouble (1995)
# Clickstream Status:  True
# Streaming event:  1 Microcosmos: Le peuple de l'herbe (1996)
# Clickstream Status:  True
# Streaming event:  1 Body Snatcher, The (1945)
# Clickstream Status:  True
# Streaming event:  1 Arrival, The (1996)
# Clickstream Status:  True
# Streaming event:  1 T-Men (1947)
# Clickstream Status:  True
# Streaming event:  1 Raising Arizona (1987)
# Clickstream Status:  True
# Streaming event:  1 Mille bolle blu (1993)
# Clickstream Status:  True
# Streaming event:  1 Mrs. Dalloway (1997)
# Clickstream Status:  True
# Streaming event:  1 Oliver & Company (1988)
# Clickstream Status:  True
# Streaming event:  2 Batman Returns (1992)
# Clickstream Status:  True
# Streaming event:  2 Shall We Dance? (1996)
# Clickstream Status:  True
# Streaming event:  2 Arrival, The (1996)
# Clickstream Status:  True
# Streaming event:  2 Catwalk (1995)
# Clickstream Status:  True
# Streaming event:  2 Losing Chase (1996)
# Clickstream Status:  True
# Streaming event:  2 Barb Wire (1996)
# Clickstream Status:  True
# Streaming event:  2 Cyrano de Bergerac (1990)
# Clickstream Status:  True
# Streaming event:  2 Everyone Says I Love You (1996)
# Clickstream Status:  True
# Streaming event:  2 I Can't Sleep (J'ai pas sommeil) (1994)
# Clickstream Status:  True
# Streaming event:  2 Independence Day (ID4) (1996)
# Clickstream Status:  True
# Streaming event:  2 Sphere (1998)
# Clickstream Status:  True
# Streaming event:  2 Sword in the Stone, The (1963)
# Clickstream Status:  True
# Streaming event:  2 Clerks (1994)
# Clickstream Status:  True
# Streaming event:  2 Thin Blue Line, The (1988)
# Clickstream Status:  True
# Streaming event:  2 Manchurian Candidate, The (1962)
# Clickstream Status:  True
# Streaming event:  2 Warriors of Virtue (1997)
# Clickstream Status:  True
# Streaming event:  2 Gaslight (1944)
# Clickstream Status:  True
# Streaming event:  2 Harlem (1993)
# Clickstream Status:  True
# Streaming event:  2 Mimic (1997)
# Clickstream Status:  True
# Streaming event:  2 Associate, The (1996)
# Clickstream Status:  True
# Streaming event:  2 Reality Bites (1994)
# Clickstream Status:  True
# Streaming event:  2 Romy and Michele's High School Reunion (1997)
# Clickstream Status:  True
# Streaming event:  2 Wishmaster (1997)
# Clickstream Status:  True
# Streaming event:  2 Stripes (1981)
# Clickstream Status:  True
# Streaming event:  2 Beyond Rangoon (1995)
# Clickstream Status:  True
# Streaming event:  2 Shooting Fish (1997)
# Clickstream Status:  True
# Streaming event:  2 Being Human (1993)
# Clickstream Status:  True
# Streaming event:  2 White Balloon, The (1995)
# Clickstream Status:  True
# Streaming event:  2 Cyclo (1995)
# Clickstream Status:  True
# Streaming event:  2 Man Who Would Be King, The (1975)
# Clickstream Status:  True
# Streaming event:  2 Manhattan (1979)
# Clickstream Status:  True
# Streaming event:  2 Carpool (1996)
# Clickstream Status:  True
# Streaming event:  2 Escape from New York (1981)
# Clickstream Status:  True
# Streaming event:  2 Life with Mikey (1993)
# Clickstream Status:  True
# Streaming event:  2 Night on Earth (1991)
# Clickstream Status:  True
# Streaming event:  2 Legal Deceit (1997)
# Clickstream Status:  True
# Streaming event:  2 G.I. Jane (1997)
# Clickstream Status:  True
# Streaming event:  2 Caro Diario (Dear Diary) (1994)
# Clickstream Status:  True
# Streaming event:  2 Meet John Doe (1941)
# Clickstream Status:  True
# Streaming event:  2 Blood & Wine (1997)
# Clickstream Status:  True
# Streaming event:  2 Amityville 3-D (1983)
# Clickstream Status:  True
# Streaming event:  2 Speed 2: Cruise Control (1997)
# Clickstream Status:  True
# Streaming event:  2 Fifth Element, The (1997)
# Clickstream Status:  True
# Streaming event:  2 If Lucy Fell (1996)
# Clickstream Status:  True
# Streaming event:  2 Man Without a Face, The (1993)
# Clickstream Status:  True
# Streaming event:  2 Very Natural Thing, A (1974)
# Clickstream Status:  True
# Streaming event:  2 Clean Slate (Coup de Torchon) (1981)
# Clickstream Status:  True
# Streaming event:  2 Mr. Jones (1993)
# Clickstream Status:  True
# Streaming event:  2 Sabrina (1954)
# Clickstream Status:  True
# Streaming event:  2 Santa Clause, The (1994)
# Clickstream Status:  True
# Streaming event:  2 Of Love and Shadows (1994)
# Clickstream Status:  True
# Streaming event:  2 MatchMaker, The (1997)
# Clickstream Status:  True
# Streaming event:  2 Associate, The (1996)
# Clickstream Status:  True
# Streaming event:  2 Glimmer Man, The (1996)
# Clickstream Status:  True
# Streaming event:  2 Madonna: Truth or Dare (1991)
# Clickstream Status:  True
# Streaming event:  2 To Kill a Mockingbird (1962)
# Clickstream Status:  True
# Streaming event:  2 Good Morning (1971)
# Clickstream Status:  True
# Streaming event:  2 That Darn Cat! (1965)
# Clickstream Status:  True
# Streaming event:  2 Relative Fear (1994)
# Clickstream Status:  True
# Streaming event:  2 Trainspotting (1996)
# Clickstream Status:  True
# Streaming event:  2 Bushwhacked (1995)
# Clickstream Status:  True
# Streaming event:  2 Best Men (1997)
# Clickstream Status:  True
# Streaming event:  2 Pete's Dragon (1977)
# Clickstream Status:  True
# Streaming event:  2 Bad Moon (1996)
# Clickstream Status:  True
# Streaming event:  2 Temptress Moon (Feng Yue) (1996)
# Clickstream Status:  True
# Streaming event:  2 Mimic (1997)
# Clickstream Status:  True
# Streaming event:  2 Nightmare on Elm Street, A (1984)
# Clickstream Status:  True
# Streaming event:  2 Operation Dumbo Drop (1995)
# Clickstream Status:  True
# Streaming event:  2 It Happened One Night (1934)
# Clickstream Status:  True
# Streaming event:  2 Full Metal Jacket (1987)
# Clickstream Status:  True
# Streaming event:  2 Fearless (1993)
# Clickstream Status:  True
# Streaming event:  2 Rainmaker, The (1997)
# Clickstream Status:  True
# Streaming event:  2 Frisk (1995)
# Clickstream Status:  True
# Streaming event:  2 Clear and Present Danger (1994)
# Clickstream Status:  True
# Streaming event:  2 Liebelei (1933)
# Clickstream Status:  True
# Streaming event:  2 Total Eclipse (1995)
# Clickstream Status:  True
# Streaming event:  2 House Arrest (1996)
# Clickstream Status:  True
# Streaming event:  2 8 1/2 (1963)
# Clickstream Status:  True
# Streaming event:  2 Promise, The (Versprechen, Das) (1994)
# Clickstream Status:  True
# Streaming event:  2 Princess Caraboo (1994)
# Clickstream Status:  True
# Streaming event:  2 Invitation, The (Zaproszenie) (1986)
# Clickstream Status:  True
# Streaming event:  2 Inspector General, The (1949)
# Clickstream Status:  True
# Streaming event:  2 Just Cause (1995)
# Clickstream Status:  True
# Streaming event:  2 Johns (1996)
# Clickstream Status:  True
# Streaming event:  2 Nell (1994)
# Clickstream Status:  True
# Streaming event:  2 Total Eclipse (1995)
# Clickstream Status:  True
# Streaming event:  2 Larger Than Life (1996)
# Clickstream Status:  True
# Streaming event:  2 Body Snatchers (1993)
# Clickstream Status:  True
# Streaming event:  2 Little Lord Fauntleroy (1936)
# Clickstream Status:  True
# Streaming event:  2 Simple Wish, A (1997)
# Clickstream Status:  True
# Streaming event:  2 Terminal Velocity (1994)
# Clickstream Status:  True
# Streaming event:  2 Old Man and the Sea, The (1958)
# Clickstream Status:  True
# Streaming event:  2 Bent (1997)
# Clickstream Status:  True
# Streaming event:  2 Madame Butterfly (1995)
# Clickstream Status:  True
# Streaming event:  2 Hercules (1997)
# Clickstream Status:  True
# Streaming event:  2 Big Blue, The (Grand bleu, Le) (1988)
# Clickstream Status:  True
# Streaming event:  2 River Wild, The (1994)
# Clickstream Status:  True
# Streaming event:  2 Delta of Venus (1994)
# Clickstream Status:  True
# Streaming event:  2 Butcher Boy, The (1998)
# Clickstream Status:  True
# Streaming event:  3 Letter From Death Row, A (1998)
# Clickstream Status:  True
# Streaming event:  3 Big One, The (1997)
# Clickstream Status:  True
# Streaming event:  3 Ridicule (1996)
# Clickstream Status:  True
# Streaming event:  3 Bride of Frankenstein (1935)
# Clickstream Status:  True
# Streaming event:  3 For Ever Mozart (1996)
# Clickstream Status:  True
# Streaming event:  3 Fear of a Black Hat (1993)
# Clickstream Status:  True
# Streaming event:  3 North by Northwest (1959)
# Clickstream Status:  True
# Streaming event:  3 187 (1997)
# Clickstream Status:  True
# Streaming event:  3 Inspector General, The (1949)
# Clickstream Status:  True
# Streaming event:  3 Johnny Mnemonic (1995)
# Clickstream Status:  True
# Streaming event:  3 Dead Man Walking (1995)
# Clickstream Status:  True
# Streaming event:  3 Monty Python and the Holy Grail (1974)
# Clickstream Status:  True
# Streaming event:  3 Gone Fishin' (1997)
# Clickstream Status:  True
# Streaming event:  3 Second Jungle Book: Mowgli & Baloo, The (1997)
# Clickstream Status:  True
# Streaming event:  3 Angela (1995)
# Clickstream Status:  True
# Streaming event:  3 Good Morning (1971)
# Clickstream Status:  True
# Streaming event:  3 Rob Roy (1995)
# Clickstream Status:  True
# Streaming event:  3 Roseanna's Grave (For Roseanna) (1997)
# Clickstream Status:  True
# Streaming event:  3 Escape to Witch Mountain (1975)
# Clickstream Status:  True
# Streaming event:  3 Hearts and Minds (1996)
# Clickstream Status:  True
# Streaming event:  3 Heat (1995)
# Clickstream Status:  True
# Streaming event:  3 Enchanted April (1991)
# Clickstream Status:  True
# Streaming event:  3 Blue in the Face (1995)
# Clickstream Status:  True
# Streaming event:  3 Visitors, The (Visiteurs, Les) (1993)
# Clickstream Status:  True
# Streaming event:  3 I Know What You Did Last Summer (1997)
# Clickstream Status:  True
# Streaming event:  3 Blues Brothers, The (1980)
# Clickstream Status:  True
# Streaming event:  3 Indian Summer (1996)
# Clickstream Status:  True
# Streaming event:  3 Substitute, The (1996)
# Clickstream Status:  True
# Streaming event:  3 Grace of My Heart (1996)
# Clickstream Status:  True
# Streaming event:  3 Top Gun (1986)
# Clickstream Status:  True
# Streaming event:  3 Mary Shelley's Frankenstein (1994)
# Clickstream Status:  True
# Streaming event:  3 Assassins (1995)
# Clickstream Status:  True
# Streaming event:  3 Waiting to Exhale (1995)
# Clickstream Status:  True
# Streaming event:  3 Kalifornia (1993)
# Clickstream Status:  True
# Streaming event:  3 In the Company of Men (1997)
# Clickstream Status:  True
# Streaming event:  3 Patton (1970)
# Clickstream Status:  True
# Streaming event:  3 Vampire in Brooklyn (1995)
# Clickstream Status:  True
# Streaming event:  3 Home Alone 3 (1997)
# Clickstream Status:  True
# Streaming event:  3 Postman, The (1997)
# Clickstream Status:  True
# Streaming event:  3 Metisse (Café au Lait) (1993)
# Clickstream Status:  True
# Streaming event:  3 Things to Do in Denver when You're Dead (1995)
# Clickstream Status:  True
# Streaming event:  3 Kid in King Arthur's Court, A (1995)
# Clickstream Status:  True
# Streaming event:  3 Amistad (1997)
# Clickstream Status:  True
# Streaming event:  3 Hunted, The (1995)
# Clickstream Status:  True
# Streaming event:  3 Amityville Curse, The (1990)
# Clickstream Status:  True
# Streaming event:  3 Inkwell, The (1994)
# Clickstream Status:  True
# Streaming event:  3 Police Story 4: Project S (Chao ji ji hua) (1993)
# Clickstream Status:  True
# Streaming event:  3 Golden Earrings (1947)
# Clickstream Status:  True
# Streaming event:  3 Hudsucker Proxy, The (1994)
# Clickstream Status:  True
# Streaming event:  3 Amityville 1992: It's About Time (1992)
# Clickstream Status:  True
# Streaming event:  3 Pharaoh's Army (1995)
# Clickstream Status:  True
# Streaming event:  3 Craft, The (1996)
# Clickstream Status:  True
# Streaming event:  3 Daytrippers, The (1996)
# Clickstream Status:  True
# Streaming event:  3 Shadow Conspiracy (1997)
# Clickstream Status:  True
# Streaming event:  3 Kaspar Hauser (1993)
# Clickstream Status:  True
# Streaming event:  3 Ace Ventura: When Nature Calls (1995)
# Clickstream Status:  True
# Streaming event:  3 Renaissance Man (1994)
# Clickstream Status:  True
# Streaming event:  3 North (1994)
# Clickstream Status:  True
# Streaming event:  3 Sixth Man, The (1997)
# Clickstream Status:  True
# Streaming event:  3 Great Day in Harlem, A (1994)
# Clickstream Status:  True
# Streaming event:  3 Addicted to Love (1997)
# Clickstream Status:  True
# Streaming event:  3 Wonderful, Horrible Life of Leni Riefenstahl, The (1993)
# Clickstream Status:  True
# Streaming event:  3 Swan Princess, The (1994)
# Clickstream Status:  True
# Streaming event:  3 Pallbearer, The (1996)
# Clickstream Status:  True
# Streaming event:  3 Hunted, The (1995)
# Clickstream Status:  True
# Streaming event:  3 Woman in Question, The (1950)
# Clickstream Status:  True
# Streaming event:  3 Quiz Show (1994)
# Clickstream Status:  True
# Streaming event:  3 Striptease (1996)
# Clickstream Status:  True
# Streaming event:  3 Indian in the Cupboard, The (1995)
# Clickstream Status:  True
# Streaming event:  3 Pump Up the Volume (1990)
# Clickstream Status:  True
# Streaming event:  3 Professional, The (1994)
# Clickstream Status:  True
# Streaming event:  3 Escape to Witch Mountain (1975)
# Clickstream Status:  True
# Streaming event:  3 Milk Money (1994)
# Clickstream Status:  True
# Streaming event:  3 He Walked by Night (1948)
# Clickstream Status:  True
# Streaming event:  3 Raiders of the Lost Ark (1981)
# Clickstream Status:  True
# Streaming event:  3 King of the Hill (1993)
# Clickstream Status:  True
# Streaming event:  3 Go Fish (1994)
# Clickstream Status:  True
# Streaming event:  3 Blob, The (1958)
# Clickstream Status:  True
# Streaming event:  3 Before the Rain (Pred dozhdot) (1994)
# Clickstream Status:  True
# Streaming event:  3 Dumbo (1941)
# Clickstream Status:  True
# Streaming event:  3 Stand by Me (1986)
# Clickstream Status:  True
# Streaming event:  3 Free Willy 3: The Rescue (1997)
# Clickstream Status:  True
# Streaming event:  3 Kim (1950)
# Clickstream Status:  True
# Streaming event:  3 Swiss Family Robinson (1960)
# Clickstream Status:  True
# Streaming event:  3 Pie in the Sky (1995)
# Clickstream Status:  True
# Streaming event:  3 Bedknobs and Broomsticks (1971)
# Clickstream Status:  True
# Streaming event:  3 Candidate, The (1972)
# Clickstream Status:  True
# Streaming event:  3 Judgment Night (1993)
# Clickstream Status:  True
# Streaming event:  3 Trial by Jury (1994)
# Clickstream Status:  True
# Streaming event:  3 My Family (1995)
# Clickstream Status:  True
# Streaming event:  3 Kim (1950)
# Clickstream Status:  True
# Streaming event:  3 Low Down Dirty Shame, A (1994)
# Clickstream Status:  True
# Streaming event:  3 Lassie (1994)
# Clickstream Status:  True
# Streaming event:  3 Bad Boys (1995)
# Clickstream Status:  True
# Streaming event:  3 Net, The (1995)
# Clickstream Status:  True
# Streaming event:  3 Paris, France (1993)
# Clickstream Status:  True
# Streaming event:  3 Star Trek III: The Search for Spock (1984)
# Clickstream Status:  True
# Streaming event:  3 Kiss of Death (1995)
# Clickstream Status:  True
# Streaming event:  3 Thin Blue Line, The (1988)
# Clickstream Status:  True
# Streaming event:  4 Spanking the Monkey (1994)
# Clickstream Status:  True
# Streaming event:  4 New York Cop (1996)
# Clickstream Status:  True
# Streaming event:  4 Balto (1995)
# Clickstream Status:  True
# Streaming event:  4 Maverick (1994)
# Clickstream Status:  True
# Streaming event:  4 Empire Strikes Back, The (1980)
# Clickstream Status:  True
# Streaming event:  4 Chairman of the Board (1998)
# Clickstream Status:  True
# Streaming event:  4 Joy Luck Club, The (1993)
# Clickstream Status:  True
# Streaming event:  4 Barb Wire (1996)
# Clickstream Status:  True
# Streaming event:  4 Sliding Doors (1998)
# Clickstream Status:  True
# Streaming event:  4 Roseanna's Grave (For Roseanna) (1997)
# Clickstream Status:  True
# Streaming event:  4 Air Bud (1997)
# Clickstream Status:  True
# Streaming event:  4 Hearts and Minds (1996)
# Clickstream Status:  True
# Streaming event:  4 Sleepover (1995)
# Clickstream Status:  True
# Streaming event:  4 Young Guns (1988)
# Clickstream Status:  True
# Streaming event:  4 Rich Man's Wife, The (1996)
# Clickstream Status:  True
# Streaming event:  4 Inspector General, The (1949)
# Clickstream Status:  True
# Streaming event:  4 Batman (1989)
# Clickstream Status:  True
# Streaming event:  4 Jean de Florette (1986)
# Clickstream Status:  True
# Streaming event:  4 Renaissance Man (1994)
# Clickstream Status:  True
# Streaming event:  4 Richie Rich (1994)
# Clickstream Status:  True
# Streaming event:  4 White Balloon, The (1995)
# Clickstream Status:  True
# Streaming event:  4 Little Lord Fauntleroy (1936)
# Clickstream Status:  True
# Streaming event:  4 Strange Days (1995)
# Clickstream Status:  True
# Streaming event:  4 Johnny Mnemonic (1995)
# Clickstream Status:  True
# Streaming event:  4 Piano, The (1993)
# Clickstream Status:  True
# Streaming event:  4 Hana-bi (1997)
# Clickstream Status:  True
# Streaming event:  4 Last of the Mohicans, The (1992)
# Clickstream Status:  True
# Streaming event:  4 True Lies (1994)
# Clickstream Status:  True
# Streaming event:  4 Babysitter, The (1995)
# Clickstream Status:  True
# Streaming event:  4 Aladdin and the King of Thieves (1996)
# Clickstream Status:  True
# Streaming event:  4 Somebody to Love (1994)
# Clickstream Status:  True
# Streaming event:  4 Before the Rain (Pred dozhdot) (1994)
# Clickstream Status:  True
# Streaming event:  4 High Noon (1952)
# Clickstream Status:  True
# Streaming event:  4 Slingshot, The (1993)
# Clickstream Status:  True
# Streaming event:  4 My Fellow Americans (1996)
# Clickstream Status:  True
# Streaming event:  4 Airheads (1994)
# Clickstream Status:  True
# Streaming event:  4 Batman & Robin (1997)
# Clickstream Status:  True
# Streaming event:  4 Roman Holiday (1953)
# Clickstream Status:  True
# Streaming event:  4 Lover's Knot (1996)
# Clickstream Status:  True
# Streaming event:  4 Nell (1994)
# Clickstream Status:  True
# Streaming event:  4 Nobody Loves Me (Keiner liebt mich) (1994)
# Clickstream Status:  True
# Streaming event:  4 Love Jones (1997)
# Clickstream Status:  True
# Streaming event:  4 Arrival, The (1996)
# Clickstream Status:  True
# Streaming event:  4 Little Big League (1994)
# Clickstream Status:  True
# Streaming event:  4 Pharaoh's Army (1995)
# Clickstream Status:  True
# Streaming event:  4 To Kill a Mockingbird (1962)
# Clickstream Status:  True
# Streaming event:  4 Lamerica (1994)
# Clickstream Status:  True
# Streaming event:  4 Dolores Claiborne (1994)
# Clickstream Status:  True
# Streaming event:  4 Weekend at Bernie's (1989)
# Clickstream Status:  True
# Streaming event:  4 Getting Away With Murder (1996)
# Clickstream Status:  True
# Streaming event:  4 Sliding Doors (1998)
# Clickstream Status:  True
# Streaming event:  4 Neon Bible, The (1995)
# Clickstream Status:  True
# Streaming event:  4 Multiplicity (1996)
# Clickstream Status:  True
# Streaming event:  4 Mostro, Il (1994)
# Clickstream Status:  True
# Streaming event:  4 Ayn Rand: A Sense of Life (1997)
# Clickstream Status:  True
# Streaming event:  4 Some Like It Hot (1959)
# Clickstream Status:  True
# Streaming event:  4 Rosencrantz and Guildenstern Are Dead (1990)
# Clickstream Status:  True
# Streaming event:  4 Touki Bouki (Journey of the Hyena) (1973)
# Clickstream Status:  True
# Streaming event:  4 Mighty, The (1998)
# Clickstream Status:  True
# Streaming event:  4 Vegas Vacation (1997)
# Clickstream Status:  True
# Streaming event:  4 Big Sleep, The (1946)
# Clickstream Status:  True
# Streaming event:  4 Air Bud (1997)
# Clickstream Status:  True
# Streaming event:  4 House of Yes, The (1997)
# Clickstream Status:  True
# Streaming event:  4 Strictly Ballroom (1992)
# Clickstream Status:  True
# Streaming event:  4 Trial and Error (1997)
# Clickstream Status:  True
# Streaming event:  4 Jefferson in Paris (1995)
# Clickstream Status:  True
# Streaming event:  4 Tales From the Crypt Presents: Demon Knight (1995)
# Clickstream Status:  True
# Streaming event:  4 Grosse Fatigue (1994)
# Clickstream Status:  True
# Streaming event:  4 Everest (1998)
# Clickstream Status:  True
# Streaming event:  4 Paris, France (1993)
# Clickstream Status:  True
# Streaming event:  4 Colonel Chabert, Le (1994)
# Clickstream Status:  True
# Streaming event:  4 Preacher's Wife, The (1996)
# Clickstream Status:  True
# Streaming event:  4 Two Deaths (1995)
# Clickstream Status:  True
# Streaming event:  4 Kicking and Screaming (1995)
# Clickstream Status:  True
# Streaming event:  4 Flirting With Disaster (1996)
# Clickstream Status:  True
# Streaming event:  4 Starship Troopers (1997)
# Clickstream Status:  True
# Streaming event:  4 Good Morning (1971)
# Clickstream Status:  True
# Streaming event:  4 Nikita (La Femme Nikita) (1990)
# Clickstream Status:  True
# Streaming event:  4 Like Water For Chocolate (Como agua para chocolate) (1992)
# Clickstream Status:  True
# Streaming event:  4 Savage Nights (Nuits fauves, Les) (1992)
# Clickstream Status:  True
# Streaming event:  4 Ruling Class, The (1972)
# Clickstream Status:  True
# Streaming event:  4 Three Wishes (1995)
# Clickstream Status:  True
# Streaming event:  4 Kaspar Hauser (1993)
# Clickstream Status:  True
# Streaming event:  4 Heavy Metal (1981)
# Clickstream Status:  True
# Streaming event:  4 Tank Girl (1995)
# Clickstream Status:  True
# Streaming event:  4 Vertigo (1958)
# Clickstream Status:  True
# Streaming event:  4 Picture Perfect (1997)
# Clickstream Status:  True
# Streaming event:  4 Boys of St. Vincent, The (1993)
# Clickstream Status:  True
# Streaming event:  4 Nico Icon (1995)
# Clickstream Status:  True
# Streaming event:  4 Tigrero: A Film That Was Never Made (1994)
# Clickstream Status:  True
# Streaming event:  4 Jackal, The (1997)
# Clickstream Status:  True
# Streaming event:  4 Truth or Consequences, N.M. (1997)
# Clickstream Status:  True
# Streaming event:  4 2 Days in the Valley (1996)
# Clickstream Status:  True
# Streaming event:  4 Man from Down Under, The (1943)
# Clickstream Status:  True
# Streaming event:  4 Price Above Rubies, A (1998)
# Clickstream Status:  True
# Streaming event:  4 Farewell My Concubine (1993)
# Clickstream Status:  True
# Streaming event:  4 Fear, The (1995)
# Clickstream Status:  True
# Streaming event:  4 Species (1995)
# Clickstream Status:  True
# Streaming event:  4 Sum of Us, The (1994)
# Clickstream Status:  True
# Streaming event:  5 Victor/Victoria (1982)
# Clickstream Status:  True
# Streaming event:  5 Fear, The (1995)
# Clickstream Status:  True
# Streaming event:  5 Jaws 3-D (1983)
# Clickstream Status:  True
# Streaming event:  5 Judge Dredd (1995)
# Clickstream Status:  True
# Streaming event:  5 Bed of Roses (1996)
# Clickstream Status:  True
# Streaming event:  5 Twelve Monkeys (1995)
# Clickstream Status:  True
# Streaming event:  5 Run of the Country, The (1995)
# Clickstream Status:  True
# Streaming event:  5 Herbie Rides Again (1974)
# Clickstream Status:  True
# Streaming event:  5 Cosi (1996)
# Clickstream Status:  True
# Streaming event:  5 Remains of the Day, The (1993)
# Clickstream Status:  True
# Streaming event:  5 Locusts, The (1997)
# Clickstream Status:  True
# Streaming event:  5 Evil Dead II (1987)
# Clickstream Status:  True
# Streaming event:  5 Love Bug, The (1969)
# Clickstream Status:  True
# Streaming event:  5 Maybe, Maybe Not (Bewegte Mann, Der) (1994)
# Clickstream Status:  True
# Streaming event:  5 Amityville 3-D (1983)
# Clickstream Status:  True
# Streaming event:  5 Pillow Book, The (1995)
# Clickstream Status:  True
# Streaming event:  5 Seventh Seal, The (Sjunde inseglet, Det) (1957)
# Clickstream Status:  True
# Streaming event:  5 Flirt (1995)
# Clickstream Status:  True
# Streaming event:  5 Aliens (1986)
# Clickstream Status:  True
# Streaming event:  5 Promesse, La (1996)
# Clickstream Status:  True
# Streaming event:  5 Pie in the Sky (1995)
# Clickstream Status:  True
# Streaming event:  5 Like Water For Chocolate (Como agua para chocolate) (1992)
# Clickstream Status:  True
# Streaming event:  5 Batman & Robin (1997)
# Clickstream Status:  True
# Streaming event:  5 Highlander (1986)
# Clickstream Status:  True
# Streaming event:  5 Dream With the Fishes (1997)
# Clickstream Status:  True
# Streaming event:  5 As Good As It Gets (1997)
# Clickstream Status:  True
# Streaming event:  5 Tales from the Crypt Presents: Bordello of Blood (1996)
# Clickstream Status:  True
# Streaming event:  5 Crooklyn (1994)
# Clickstream Status:  True
# Streaming event:  5 Crying Game, The (1992)
# Clickstream Status:  True
# Streaming event:  5 Circle of Friends (1995)
# Clickstream Status:  True
# Streaming event:  5 Once Were Warriors (1994)
# Clickstream Status:  True
# Streaming event:  5 Paradise Lost: The Child Murders at Robin Hood Hills (1996)
# Clickstream Status:  True
# Streaming event:  5 Mark of Zorro, The (1940)
# Clickstream Status:  True
# Streaming event:  5 Endless Summer 2, The (1994)
# Clickstream Status:  True
# Streaming event:  5 Mortal Kombat: Annihilation (1997)
# Clickstream Status:  True
# Streaming event:  5 Somewhere in Time (1980)
# Clickstream Status:  True
# Streaming event:  5 Chairman of the Board (1998)
# Clickstream Status:  True
# Streaming event:  5 Moonlight and Valentino (1995)
# Clickstream Status:  True
# Streaming event:  5 Casper (1995)
# Clickstream Status:  True
# Streaming event:  5 Cutthroat Island (1995)
# Clickstream Status:  True
# Streaming event:  5 English Patient, The (1996)
# Clickstream Status:  True
# Streaming event:  5 Addiction, The (1995)
# Clickstream Status:  True
# Streaming event:  5 Usual Suspects, The (1995)
# Clickstream Status:  True
# Streaming event:  5 Sunset Park (1996)
# Clickstream Status:  True
# Streaming event:  5 Miracle on 34th Street (1994)
# Clickstream Status:  True
# Streaming event:  5 Wild Things (1998)
# Clickstream Status:  True
# Streaming event:  5 Geronimo: An American Legend (1993)
# Clickstream Status:  True
# Streaming event:  5 Gordy (1995)
# Clickstream Status:  True
# Streaming event:  5 Hearts and Minds (1996)
# Clickstream Status:  True
# Streaming event:  5 Deconstructing Harry (1997)
# Clickstream Status:  True
# Streaming event:  5 Tombstone (1993)
# Clickstream Status:  True
# Streaming event:  5 Kim (1950)
# Clickstream Status:  True
# Streaming event:  5 Pocahontas (1995)
# Clickstream Status:  True
# Streaming event:  5 Glengarry Glen Ross (1992)
# Clickstream Status:  True
# Streaming event:  5 With Honors (1994)
# Clickstream Status:  True
# Streaming event:  5 My Fellow Americans (1996)
# Clickstream Status:  True
# Streaming event:  5 Hard Eight (1996)
# Clickstream Status:  True
# Streaming event:  5 Bean (1997)
# Clickstream Status:  True
# Streaming event:  5 Postman, The (1997)
# Clickstream Status:  True
# Streaming event:  5 Man Without a Face, The (1993)
# Clickstream Status:  True
# Streaming event:  5 Mirror Has Two Faces, The (1996)
# Clickstream Status:  True
# Streaming event:  5 Village of the Damned (1995)
# Clickstream Status:  True
# Streaming event:  5 Sleepers (1996)
# Clickstream Status:  True
# Streaming event:  5 Basquiat (1996)
# Clickstream Status:  True
# Streaming event:  5 Celestial Clockwork (1994)
# Clickstream Status:  True
# Streaming event:  5 Showgirls (1995)
# Clickstream Status:  True
# Streaming event:  5 Schindler's List (1993)
# Clickstream Status:  True
# Streaming event:  5 Wings of Desire (1987)
# Clickstream Status:  True
# Streaming event:  5 Madame Butterfly (1995)
# Clickstream Status:  True
# Streaming event:  5 It's a Wonderful Life (1946)
# Clickstream Status:  True
# Streaming event:  5 Six Degrees of Separation (1993)
# Clickstream Status:  True
# Streaming event:  5 Sliding Doors (1998)
# Clickstream Status:  True
# Streaming event:  5 Naked in New York (1994)
# Clickstream Status:  True
# Streaming event:  5 One Night Stand (1997)
# Clickstream Status:  True
# Streaming event:  5 Clockers (1995)
# Clickstream Status:  True
# Streaming event:  5 Multiplicity (1996)
# Clickstream Status:  True
# Streaming event:  5 Phantom, The (1996)
# Clickstream Status:  True
# Streaming event:  5 Tainted (1998)
# Clickstream Status:  True
# Streaming event:  5 The Courtyard (1995)
# Clickstream Status:  True
# Streaming event:  5 Bram Stoker's Dracula (1992)
# Clickstream Status:  True
# Streaming event:  5 SubUrbia (1997)
# Clickstream Status:  True
# Streaming event:  5 Entertaining Angels: The Dorothy Day Story (1996)
# Clickstream Status:  True
# Streaming event:  5 Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)
# Clickstream Status:  True
# Streaming event:  5 Lawnmower Man, The (1992)
# Clickstream Status:  True
# Streaming event:  5 French Twist (Gazon maudit) (1995)
# Clickstream Status:  True
# Streaming event:  5 Jeffrey (1995)
# Clickstream Status:  True
# Streaming event:  5 Bringing Up Baby (1938)
# Clickstream Status:  True
# Streaming event:  5 Careful (1992)
# Clickstream Status:  True
# Streaming event:  5 Devil's Advocate, The (1997)
# Clickstream Status:  True
# Streaming event:  5 Thieves (Voleurs, Les) (1996)
# Clickstream Status:  True
# Streaming event:  5 Little Big League (1994)
# Clickstream Status:  True
# Streaming event:  5 Roseanna's Grave (For Roseanna) (1997)
# Clickstream Status:  True
# Streaming event:  5 Two Bits (1995)
# Clickstream Status:  True
# Streaming event:  5 Blob, The (1958)
# Clickstream Status:  True
# Streaming event:  5 Trainspotting (1996)
# Clickstream Status:  True
# Streaming event:  5 Rosewood (1997)
# Clickstream Status:  True
# Streaming event:  5 Crucible, The (1996)
# Clickstream Status:  True
# Streaming event:  5 Unstrung Heroes (1995)
# Clickstream Status:  True
# Streaming event:  5 Batman Forever (1995)
# Clickstream Status:  True
# Streaming event:  6 Road to Wellville, The (1994)
# Clickstream Status:  True
# Streaming event:  6 Return of Martin Guerre, The (Retour de Martin Guerre, Le) (1982)
# Clickstream Status:  True
# Streaming event:  6 Interview with the Vampire (1994)
# Clickstream Status:  True
# Streaming event:  6 Secret Agent, The (1996)
# Clickstream Status:  True
# Streaming event:  6 Locusts, The (1997)
# Clickstream Status:  True
# Streaming event:  6 Apple Dumpling Gang, The (1975)
# Clickstream Status:  True
# Streaming event:  6 Gridlock'd (1997)
# Clickstream Status:  True
# Streaming event:  6 Priest (1994)
# Clickstream Status:  True
# Streaming event:  6 Three Musketeers, The (1993)
# Clickstream Status:  True
# Streaming event:  6 Ed's Next Move (1996)
# Clickstream Status:  True
# Streaming event:  6 Boxing Helena (1993)
# Clickstream Status:  True
# Streaming event:  6 Coneheads (1993)
# Clickstream Status:  True
# Streaming event:  6 Foxfire (1996)
# Clickstream Status:  True
# Streaming event:  6 Wooden Man's Bride, The (Wu Kui) (1994)
# Clickstream Status:  True
# Streaming event:  6 Graduate, The (1967)
# Clickstream Status:  True
# Streaming event:  6 Funeral, The (1996)
# Clickstream Status:  True
# Streaming event:  6 Schizopolis (1996)
# Clickstream Status:  True
# Streaming event:  6 Shooter, The (1995)
# Clickstream Status:  True
# Streaming event:  6 I Can't Sleep (J'ai pas sommeil) (1994)
# Clickstream Status:  True
# Streaming event:  6 Family Thing, A (1996)
# Clickstream Status:  True
# Streaming event:  6 Once Upon a Time... When We Were Colored (1995)
# Clickstream Status:  True
# Streaming event:  6 Unzipped (1995)
# Clickstream Status:  True
# Streaming event:  6 Clockwork Orange, A (1971)
# Clickstream Status:  True
# Streaming event:  6 Mad Dog Time (1996)
# Clickstream Status:  True
# Streaming event:  6 Glengarry Glen Ross (1992)
# Clickstream Status:  True
# Streaming event:  6 Shadows (Cienie) (1988)
# Clickstream Status:  True
# Streaming event:  6 Boxing Helena (1993)
# Clickstream Status:  True
# Streaming event:  6 Miller's Crossing (1990)
# Clickstream Status:  True
# Streaming event:  6 Chairman of the Board (1998)
# Clickstream Status:  True
# Streaming event:  6 Phantom, The (1996)
# Clickstream Status:  True
# Streaming event:  6 Escape from New York (1981)
# Clickstream Status:  True
# Streaming event:  6 Man of the House (1995)
# Clickstream Status:  True
# Streaming event:  6 Aristocats, The (1970)
# Clickstream Status:  True
# Streaming event:  6 Mr. Wonderful (1993)
# Clickstream Status:  True
# Streaming event:  6 Time to Kill, A (1996)
# Clickstream Status:  True
# Streaming event:  6 My Left Foot (1989)
# Clickstream Status:  True
# Streaming event:  6 Indiana Jones and the Last Crusade (1989)
# Clickstream Status:  True
# Streaming event:  6 Underneath, The (1995)
# Clickstream Status:  True
# Streaming event:  6 Bronx Tale, A (1993)
# Clickstream Status:  True
# Streaming event:  6 Fargo (1996)
# Clickstream Status:  True
# Streaming event:  6 Spirits of the Dead (Tre passi nel delirio) (1968)
# Clickstream Status:  True
# Streaming event:  6 This Is Spinal Tap (1984)
# Clickstream Status:  True
# Streaming event:  6 Mimic (1997)
# Clickstream Status:  True
# Streaming event:  6 His Girl Friday (1940)
# Clickstream Status:  True
# Streaming event:  6 Critical Care (1997)
# Clickstream Status:  True
# Streaming event:  6 Heavenly Creatures (1994)
# Clickstream Status:  True
# Streaming event:  6 Lassie (1994)
# Clickstream Status:  True
# Streaming event:  6 Platoon (1986)
# Clickstream Status:  True
# Streaming event:  6 Evil Dead II (1987)
# Clickstream Status:  True
# Streaming event:  6 Dangerous Beauty (1998)
# Clickstream Status:  True
# Streaming event:  6 Stealing Beauty (1996)
# Clickstream Status:  True
# Streaming event:  6 Gilligan's Island: The Movie (1998)
# Clickstream Status:  True
# Streaming event:  6 Glimmer Man, The (1996)
# Clickstream Status:  True
# Streaming event:  6 Gumby: The Movie (1995)
# Clickstream Status:  True
# Streaming event:  6 Walkabout (1971)
# Clickstream Status:  True
# Streaming event:  6 Rendezvous in Paris (Rendez-vous de Paris, Les) (1995)
# Clickstream Status:  True
# Streaming event:  6 Batman (1989)
# Clickstream Status:  True
# Streaming event:  6 Persuasion (1995)
# Clickstream Status:  True
# Streaming event:  6 Waiting for Guffman (1996)
# Clickstream Status:  True
# Streaming event:  6 187 (1997)
# Clickstream Status:  True
# Streaming event:  6 Selena (1997)
# Clickstream Status:  True
# Streaming event:  6 In the Realm of the Senses (Ai no corrida) (1976)
# Clickstream Status:  True
# Streaming event:  6 Promise, The (Versprechen, Das) (1994)
# Clickstream Status:  True
# Streaming event:  6 Girl in the Cadillac (1995)
# Clickstream Status:  True
# Streaming event:  6 Stag (1997)
# Clickstream Status:  True
# Streaming event:  6 Mad Dog Time (1996)
# Clickstream Status:  True
# Streaming event:  6 Everyone Says I Love You (1996)
# Clickstream Status:  True
# Streaming event:  6 Devil's Own, The (1997)
# Clickstream Status:  True
# Streaming event:  6 Aristocats, The (1970)
# Clickstream Status:  True
# Streaming event:  6 187 (1997)
# Clickstream Status:  True
# Streaming event:  6 Raw Deal (1948)
# Clickstream Status:  True
# Streaming event:  6 Executive Decision (1996)
# Clickstream Status:  True
# Streaming event:  6 Rent-a-Kid (1995)
# Clickstream Status:  True
# Streaming event:  6 Women, The (1939)
# Clickstream Status:  True
# Streaming event:  6 Man from Down Under, The (1943)
# Clickstream Status:  True
# Streaming event:  6 Death in the Garden (Mort en ce jardin, La) (1956)
# Clickstream Status:  True
# Streaming event:  6 Stars Fell on Henrietta, The (1995)
# Clickstream Status:  True
# Streaming event:  6 Bed of Roses (1996)
# Clickstream Status:  True
# Streaming event:  6 Jason's Lyric (1994)
# Clickstream Status:  True
# Streaming event:  6 Brother's Kiss, A (1997)
# Clickstream Status:  True
# Streaming event:  6 Manchurian Candidate, The (1962)
# Clickstream Status:  True
# Streaming event:  6 Air Bud (1997)
# Clickstream Status:  True
# Streaming event:  6 Client, The (1994)
# Clickstream Status:  True
# Streaming event:  6 Aladdin (1992)
# Clickstream Status:  True
# Streaming event:  6 Carpool (1996)
# Clickstream Status:  True
# Streaming event:  6 My Crazy Life (Mi vida loca) (1993)
# Clickstream Status:  True
# Streaming event:  6 Mrs. Parker and the Vicious Circle (1994)
# Clickstream Status:  True
# Streaming event:  6 Assassins (1995)
# Clickstream Status:  True
# Streaming event:  6 Fan, The (1996)
# Clickstream Status:  True
# Streaming event:  6 Madame Butterfly (1995)
# Clickstream Status:  True
# Streaming event:  6 Welcome to the Dollhouse (1995)
# Clickstream Status:  True
# Streaming event:  6 Time Tracers (1995)
# Clickstream Status:  True
# Streaming event:  6 Foreign Correspondent (1940)
# Clickstream Status:  True
# Streaming event:  6 Gridlock'd (1997)
# Clickstream Status:  True
# Streaming event:  6 Fled (1996)
# Clickstream Status:  True
# Streaming event:  6 2001: A Space Odyssey (1968)
# Clickstream Status:  True
# Streaming event:  6 Fatal Instinct (1993)
# Clickstream Status:  True
# Streaming event:  6 Leopard Son, The (1996)
# Clickstream Status:  True
# Streaming event:  6 Low Life, The (1994)
# Clickstream Status:  True
# Streaming event:  7 Devil's Own, The (1997)
# Clickstream Status:  True
# Streaming event:  7 How to Be a Player (1997)
# Clickstream Status:  True
# Streaming event:  7 Life with Mikey (1993)
# Clickstream Status:  True
# Streaming event:  7 Big One, The (1997)
# Clickstream Status:  True
# Streaming event:  7 Arsenic and Old Lace (1944)
# Clickstream Status:  True
# Streaming event:  7 Lashou shentan (1992)
# Clickstream Status:  True
# Streaming event:  7 Hard Eight (1996)
# Clickstream Status:  True
# Streaming event:  7 Singin' in the Rain (1952)
# Clickstream Status:  True
# Streaming event:  7 Cosi (1996)
# Clickstream Status:  True
# Streaming event:  7 City Slickers II: The Legend of Curly's Gold (1994)
# Clickstream Status:  True
# Streaming event:  7 Dead Presidents (1995)
# Clickstream Status:  True
# Streaming event:  7 Stag (1997)
# Clickstream Status:  True
# Streaming event:  7 Free Willy 3: The Rescue (1997)
# Clickstream Status:  True
# Streaming event:  7 Man in the Iron Mask, The (1998)
# Clickstream Status:  True
# Streaming event:  7 Cop Land (1997)
# Clickstream Status:  True
# Streaming event:  7 Postino, Il (1994)
# Clickstream Status:  True
# Streaming event:  7 Arsenic and Old Lace (1944)
# Clickstream Status:  True
# Streaming event:  7 Flintstones, The (1994)
# Clickstream Status:  True
# Streaming event:  7 Big One, The (1997)
# Clickstream Status:  True
# Streaming event:  7 Cutthroat Island (1995)
# Clickstream Status:  True
# Streaming event:  7 Stuart Saves His Family (1995)
# Clickstream Status:  True
# Streaming event:  7 Little Rascals, The (1994)
# Clickstream Status:  True
# Streaming event:  7 Scream of Stone (Schrei aus Stein) (1991)
# Clickstream Status:  True
# Streaming event:  7 Gumby: The Movie (1995)
# Clickstream Status:  True
# Streaming event:  7 Boys on the Side (1995)
# Clickstream Status:  True
# Streaming event:  7 Meet John Doe (1941)
# Clickstream Status:  True
# Streaming event:  7 Ill Gotten Gains (1997)
# Clickstream Status:  True
# Streaming event:  7 Princess Caraboo (1994)
# Clickstream Status:  True
# Streaming event:  7 Losing Isaiah (1995)
# Clickstream Status:  True
# Streaming event:  7 Boys of St. Vincent, The (1993)
# Clickstream Status:  True
# Streaming event:  7 Larger Than Life (1996)
# Clickstream Status:  True
# Streaming event:  7 April Fool's Day (1986)
# Clickstream Status:  True
# Streaming event:  7 In the Name of the Father (1993)
# Clickstream Status:  True
# Streaming event:  7 Kissed (1996)
# Clickstream Status:  True
# Streaming event:  7 House Party 3 (1994)
# Clickstream Status:  True
# Streaming event:  7 Theodore Rex (1995)
# Clickstream Status:  True
# Streaming event:  7 Price Above Rubies, A (1998)
# Clickstream Status:  True
# Streaming event:  7 Inspector General, The (1949)
# Clickstream Status:  True
# Streaming event:  7 Dangerous Beauty (1998)
# Clickstream Status:  True
# Streaming event:  7 Ill Gotten Gains (1997)
# Clickstream Status:  True
# Streaming event:  7 Story of Xinghua, The (1993)
# Clickstream Status:  True
# Streaming event:  7 Shall We Dance? (1996)
# Clickstream Status:  True
# Streaming event:  7 Dumb & Dumber (1994)
# Clickstream Status:  True
# Streaming event:  7 Fly Away Home (1996)
# Clickstream Status:  True
# Streaming event:  7 Eat Drink Man Woman (1994)
# Clickstream Status:  True
# Streaming event:  7 Foreign Correspondent (1940)
# Clickstream Status:  True
# Streaming event:  7 Mrs. Winterbourne (1996)
# Clickstream Status:  True
# Streaming event:  7 English Patient, The (1996)
# Clickstream Status:  True
# Streaming event:  7 Mirage (1995)
# Clickstream Status:  True
# Streaming event:  7 House Party 3 (1994)
# Clickstream Status:  True
# Streaming event:  7 Angela (1995)
# Clickstream Status:  True
# Streaming event:  7 Batman Returns (1992)
# Clickstream Status:  True
# Streaming event:  7 Love Bug, The (1969)
# Clickstream Status:  True
# Streaming event:  7 She's So Lovely (1997)
# Clickstream Status:  True
# Streaming event:  7 I Shot Andy Warhol (1996)
# Clickstream Status:  True
# Streaming event:  7 Charade (1963)
# Clickstream Status:  True
# Streaming event:  7 Sprung (1997)
# Clickstream Status:  True
# Streaming event:  7 Timecop (1994)
# Clickstream Status:  True
# Streaming event:  7 House Arrest (1996)
# Clickstream Status:  True
# Streaming event:  7 Cool Hand Luke (1967)
# Clickstream Status:  True
# Streaming event:  7 Two Deaths (1995)
# Clickstream Status:  True
# Streaming event:  7 Little Lord Fauntleroy (1936)
# Clickstream Status:  True
# Streaming event:  7 Balto (1995)
# Clickstream Status:  True
# Streaming event:  7 Falling in Love Again (1980)
# Clickstream Status:  True
# Streaming event:  7 Brady Bunch Movie, The (1995)
# Clickstream Status:  True
# Streaming event:  7 Screamers (1995)
# Clickstream Status:  True
# Streaming event:  7 Stranger, The (1994)
# Clickstream Status:  True
# Streaming event:  7 Sex, Lies, and Videotape (1989)
# Clickstream Status:  True
# Streaming event:  7 Star Maps (1997)
# Clickstream Status:  True
# Streaming event:  7 MURDER and murder (1996)
# Clickstream Status:  True
# Streaming event:  7 Harlem (1993)
# Clickstream Status:  True
# Streaming event:  7 Rosewood (1997)
# Clickstream Status:  True
# Streaming event:  7 Wes Craven's New Nightmare (1994)
# Clickstream Status:  True
# Streaming event:  7 Romy and Michele's High School Reunion (1997)
# Clickstream Status:  True
# Streaming event:  7 Rebecca (1940)
# Clickstream Status:  True
# Streaming event:  7 I Shot Andy Warhol (1996)
# Clickstream Status:  True
# Streaming event:  7 Piano, The (1993)
# Clickstream Status:  True
# Streaming event:  7 Under Siege (1992)
# Clickstream Status:  True
# Streaming event:  7 Terror in a Texas Town (1958)
# Clickstream Status:  True
# Streaming event:  7 Love Serenade (1996)
# Clickstream Status:  True
# Streaming event:  7 Murder at 1600 (1997)
# Clickstream Status:  True
# Streaming event:  7 Keys to Tulsa (1997)
# Clickstream Status:  True
# Streaming event:  7 Three Colors: Blue (1993)
# Clickstream Status:  True
# Streaming event:  7 Barcelona (1994)
# Clickstream Status:  True
# Streaming event:  7 Shooting Fish (1997)
# Clickstream Status:  True
# Streaming event:  7 Love and a .45 (1994)
# Clickstream Status:  True
# Streaming event:  7 Four Days in September (1997)
# Clickstream Status:  True
# ...
# Clickstream Status:  True
# Streaming event:  8 With Honors (1994)
# Clickstream Status:  True
# Streaming event:  8 Sophie's Choice (1982)
# Clickstream Status:  True
# Streaming event:  8 I Like It Like That (1994)
# Clickstream Status:  True
# Streaming event:  8 Wedding Singer, The (1998)
# Clickstream Status:  True
# Streaming event:  8 Angel on My Shoulder (1946)
# Clickstream Status:  True
# Streaming event:  8 Savage Nights (Nuits fauves, Les) (1992)
# Clickstream Status:  True
# Streaming event:  8 Major Payne (1994)
# Clickstream Status:  True
# Streaming event:  8 Exotica (1994)
# Clickstream Status:  True
# Streaming event:  8 Farewell My Concubine (1993)
# Clickstream Status:  True
# Streaming event:  8 Braindead (1992)
# Clickstream Status:  True
# Streaming event:  8 Vermin (1998)
# Clickstream Status:  True
# Streaming event:  8 Game, The (1997)
# Clickstream Status:  True
# Streaming event:  8 Schindler's List (1993)
# Clickstream Status:  True
# Streaming event:  8 Hunchback of Notre Dame, The (1996)
# Clickstream Status:  True
# Streaming event:  8 Chasers (1994)
# Clickstream Status:  True
# Streaming event:  8 Mother Night (1996)
# Clickstream Status:  True
# Streaming event:  8 Return of the Jedi (1983)
# Clickstream Status:  True
# Streaming event:  8 Endless Summer 2, The (1994)
# Clickstream Status:  True
# Streaming event:  8 Playing God (1997)
# Clickstream Status:  True
# Streaming event:  8 Locusts, The (1997)
# Clickstream Status:  True
# Streaming event:  8 Fear, The (1995)
# Clickstream Status:  True
# Streaming event:  8 Sex, Lies, and Videotape (1989)
# Clickstream Status:  True
# Streaming event:  8 Bride of Frankenstein (1935)
# Clickstream Status:  True
# Streaming event:  8 Ninotchka (1939)
# Clickstream Status:  True
# Streaming event:  8 Amityville Horror, The (1979)
# Clickstream Status:  True
# Streaming event:  8 This Is Spinal Tap (1984)
# Clickstream Status:  True
# Streaming event:  8 Nightwatch (1997)
# Clickstream Status:  True
# Streaming event:  8 Two Much (1996)
# Clickstream Status:  True
# Streaming event:  9 Smilla's Sense of Snow (1997)
# Clickstream Status:  True
# Streaming event:  9 Son in Law (1993)
# Clickstream Status:  True
# Streaming event:  9 Road to Wellville, The (1994)
# Clickstream Status:  True
# Streaming event:  9 Butcher Boy, The (1998)
# Clickstream Status:  True
# Streaming event:  9 Surviving the Game (1994)
# Clickstream Status:  True
# Streaming event:  9 Hard Rain (1998)
# Clickstream Status:  True
# Streaming event:  9 Bhaji on the Beach (1993)
# Clickstream Status:  True
# Streaming event:  9 First Knight (1995)
# Clickstream Status:  True
# Streaming event:  9 Adventures of Pinocchio, The (1996)
# Clickstream Status:  True
# Streaming event:  9 Braveheart (1995)
# Clickstream Status:  True
# Streaming event:  9 Mostro, Il (1994)
# Clickstream Status:  True
# Streaming event:  9 Striptease (1996)
# Clickstream Status:  True
# Streaming event:  9 Trial and Error (1997)
# Clickstream Status:  True
# Streaming event:  9 Mrs. Doubtfire (1993)
# Clickstream Status:  True
# Streaming event:  9 Twilight (1998)
# Clickstream Status:  True
# Streaming event:  9 Adventures of Priscilla, Queen of the Desert, The (1994)
# Clickstream Status:  True
# Streaming event:  9 To Wong Foo, Thanks for Everything! Julie Newmar (1995)
# Clickstream Status:  True
# Streaming event:  9 Maltese Falcon, The (1941)
# Clickstream Status:  True
# Streaming event:  9 Men With Guns (1997)
# Clickstream Status:  True
# Streaming event:  9 What's Love Got to Do with It (1993)
# Clickstream Status:  True
# Streaming event:  9 Unhook the Stars (1996)
# Clickstream Status:  True
# Streaming event:  9 Butcher Boy, The (1998)
# Clickstream Status:  True
# Streaming event:  9 Waterworld (1995)
# Clickstream Status:  True
# Streaming event:  9 Butcher Boy, The (1998)
# Clickstream Status:  True
# Streaming event:  9 Hellraiser: Bloodline (1996)
# Clickstream Status:  True
# Streaming event:  9 Star Wars (1977)
# Clickstream Status:  True
# Streaming event:  9 That Old Feeling (1997)
# Clickstream Status:  True
# Streaming event:  9 One Fine Day (1996)
# Clickstream Status:  True
# Streaming event:  9 Enchanted April (1991)
# Clickstream Status:  True
# Streaming event:  9 Ace Ventura: When Nature Calls (1995)
# Clickstream Status:  True
# Streaming event:  9 Mad Dog Time (1996)
# Clickstream Status:  True
# Streaming event:  9 Funeral, The (1996)
# Clickstream Status:  True
# Streaming event:  9 Turbo: A Power Rangers Movie (1997)
# Clickstream Status:  True
# Streaming event:  9 Event Horizon (1997)
# Clickstream Status:  True
# Streaming event:  9 Blink (1994)
# Clickstream Status:  True
# Streaming event:  9 Wild Reeds (1994)
# Clickstream Status:  True
# Streaming event:  9 Chinatown (1974)
# Clickstream Status:  True
# Streaming event:  9 Ready to Wear (Pret-A-Porter) (1994)
# Clickstream Status:  True
# Streaming event:  9 Graduate, The (1967)
# Clickstream Status:  True
# Streaming event:  9 Two Friends (1986)
# Clickstream Status:  True
# Streaming event:  9 Big Blue, The (Grand bleu, Le) (1988)
# Clickstream Status:  True
# Streaming event:  9 Gilligan's Island: The Movie (1998)
# Clickstream Status:  True
# Streaming event:  9 Living in Oblivion (1995)
# Clickstream Status:  True
# Streaming event:  9 Endless Summer 2, The (1994)
# Clickstream Status:  True
# Streaming event:  9 Second Jungle Book: Mowgli & Baloo, The (1997)
# Clickstream Status:  True
# Streaming event:  9 Alien 3 (1992)
# Clickstream Status:  True
# Streaming event:  9 Harlem (1993)
# Clickstream Status:  True
# Streaming event:  9 Richard III (1995)
# Clickstream Status:  True
# Streaming event:  9 Run of the Country, The (1995)
# Clickstream Status:  True
# Streaming event:  9 Crows and Sparrows (1949)
# Clickstream Status:  True
# Streaming event:  9 Sex, Lies, and Videotape (1989)
# Clickstream Status:  True
# Streaming event:  9 Absolute Power (1997)
# Clickstream Status:  True
# Streaming event:  9 Drop Dead Fred (1991)
# Clickstream Status:  True
# Streaming event:  9 Relic, The (1997)
# Clickstream Status:  True
# Streaming event:  9 Stars Fell on Henrietta, The (1995)
# Clickstream Status:  True
# Streaming event:  9 Shadow, The (1994)
# Clickstream Status:  True
# Streaming event:  9 Black Sheep (1996)
# Clickstream Status:  True
# Streaming event:  9 Great Race, The (1965)
# Clickstream Status:  True
# Streaming event:  9 Nothing Personal (1995)
# Clickstream Status:  True
# Streaming event:  9 Thieves (Voleurs, Les) (1996)
# Clickstream Status:  True
# Streaming event:  9 Kalifornia (1993)
# Clickstream Status:  True
# Streaming event:  9 Very Natural Thing, A (1974)
# Clickstream Status:  True
# Streaming event:  9 Virtuosity (1995)
# Clickstream Status:  True
# Streaming event:  9 Great Day in Harlem, A (1994)
# Clickstream Status:  True
# Streaming event:  9 Angel Baby (1995)
# Clickstream Status:  True
# Streaming event:  9 Gridlock'd (1997)
# Clickstream Status:  True
# Streaming event:  9 Specialist, The (1994)
# Clickstream Status:  True
# Streaming event:  9 Forrest Gump (1994)
# Clickstream Status:  True
# Streaming event:  9 Fugitive, The (1993)
# Clickstream Status:  True
# Streaming event:  9 Die xue shuang xiong (Killer, The) (1989)
# Clickstream Status:  True
# Streaming event:  9 Touki Bouki (Journey of the Hyena) (1973)
# Clickstream Status:  True
# Streaming event:  9 Mrs. Parker and the Vicious Circle (1994)
# Clickstream Status:  True
# Streaming event:  9 Seven (Se7en) (1995)
# Clickstream Status:  True
# Streaming event:  9 Cops and Robbersons (1994)
# Clickstream Status:  True
# Streaming event:  9 Joy Luck Club, The (1993)
# Clickstream Status:  True
# Streaming event:  9 It's My Party (1995)
# Clickstream Status:  True
# Streaming event:  9 Excess Baggage (1997)
# Clickstream Status:  True
# Streaming event:  9 Jaws 3-D (1983)
# Clickstream Status:  True
# Streaming event:  9 Stupids, The (1996)
# Clickstream Status:  True
# Streaming event:  9 Bram Stoker's Dracula (1992)
# Clickstream Status:  True
# Streaming event:  9 Sudden Manhattan (1996)
# Clickstream Status:  True
# Streaming event:  9 Swiss Family Robinson (1960)
# Clickstream Status:  True
# Streaming event:  9 Mad City (1997)
# Clickstream Status:  True
# Streaming event:  9 Anastasia (1997)
# Clickstream Status:  True
# Streaming event:  9 Apple Dumpling Gang, The (1975)
# Clickstream Status:  True
# Streaming event:  9 Fried Green Tomatoes (1991)
# Clickstream Status:  True
# Streaming event:  9 Madness of King George, The (1994)
# Clickstream Status:  True
# Streaming event:  9 Women, The (1939)
# Clickstream Status:  True
# Streaming event:  9 Back to the Future (1985)
# Clickstream Status:  True
# Streaming event:  9 Blue Angel, The (Blaue Engel, Der) (1930)
# Clickstream Status:  True
# Streaming event:  9 Chairman of the Board (1998)
# Clickstream Status:  True
# Streaming event:  9 Judge Dredd (1995)
# Clickstream Status:  True
# Streaming event:  9 Anastasia (1997)
# Clickstream Status:  True
# Streaming event:  9 Sleepover (1995)
# Clickstream Status:  True
# Streaming event:  9 Getting Away With Murder (1996)
# Clickstream Status:  True
# Streaming event:  9 Love Jones (1997)
# Clickstream Status:  True
# Streaming event:  9 Just Cause (1995)
# Clickstream Status:  True
# Streaming event:  9 Ruby in Paradise (1993)
# Clickstream Status:  True
# Streaming event:  9 Flipper (1996)
# Clickstream Status:  True
# Streaming event:  10 Cutthroat Island (1995)
# Clickstream Status:  True
# Streaming event:  10 Fear, The (1995)
# Clickstream Status:  True
# Streaming event:  10 Grosse Pointe Blank (1997)
# Clickstream Status:  True
# Streaming event:  10 Out to Sea (1997)
# Clickstream Status:  True
# Streaming event:  10 Crossfire (1947)
# Clickstream Status:  True
# Streaming event:  10 Things to Do in Denver when You're Dead (1995)
# Clickstream Status:  True
# Streaming event:  10 Hunchback of Notre Dame, The (1996)
# Clickstream Status:  True
# Streaming event:  10 Bushwhacked (1995)
# Clickstream Status:  True
# Streaming event:  10 Client, The (1994)
# Clickstream Status:  True
# Streaming event:  10 Hear My Song (1991)
# Clickstream Status:  True
# Streaming event:  10 Run of the Country, The (1995)
# Clickstream Status:  True
# Streaming event:  10 Rebecca (1940)
# Clickstream Status:  True
# Streaming event:  10 Beyond Bedlam (1993)
# Clickstream Status:  True
# Streaming event:  10 Bloodsport 2 (1995)
# Clickstream Status:  True
# Streaming event:  10 Giant (1956)
# Clickstream Status:  True
# Streaming event:  10 Bound (1996)
# Clickstream Status:  True
# Streaming event:  10 Desperate Measures (1998)
# Clickstream Status:  True
# Streaming event:  10 Short Cuts (1993)
# Clickstream Status:  True
# Streaming event:  10 Operation Dumbo Drop (1995)
# Clickstream Status:  True
# Streaming event:  10 Secret of Roan Inish, The (1994)
# Clickstream Status:  True
# Streaming event:  10 Wooden Man's Bride, The (Wu Kui) (1994)
# Clickstream Status:  True
# Streaming event:  10 Ed Wood (1994)
# Clickstream Status:  True
# Streaming event:  10 U Turn (1997)
# Clickstream Status:  True
# Streaming event:  10 Robert A. Heinlein's The Puppet Masters (1994)
# Clickstream Status:  True
# Streaming event:  10 Private Parts (1997)
# Clickstream Status:  True
# Streaming event:  10 Diabolique (1996)
# Clickstream Status:  True
# Streaming event:  10 Terror in a Texas Town (1958)
# Clickstream Status:  True
# Streaming event:  10 Fatal Instinct (1993)
# Clickstream Status:  True
# Streaming event:  10 Englishman Who Went Up a Hill, But Came Down a Mountain, The (1995)
# Clickstream Status:  True
# Streaming event:  10 Crying Game, The (1992)
# Clickstream Status:  True
# Streaming event:  10 House Arrest (1996)
# Clickstream Status:  True
# Streaming event:  10 Window to Paris (1994)
# Clickstream Status:  True
# Streaming event:  10 Orlando (1993)
# Clickstream Status:  True
# Streaming event:  10 Cats Don't Dance (1997)
# Clickstream Status:  True
# Streaming event:  10 Further Gesture, A (1996)
# Clickstream Status:  True
# Streaming event:  10 Heavy Metal (1981)
# Clickstream Status:  True
# Streaming event:  10 Two Much (1996)
# Clickstream Status:  True
# Streaming event:  10 Foreign Student (1994)
# Clickstream Status:  True
# Streaming event:  10 M. Butterfly (1993)
# Clickstream Status:  True
# Streaming event:  10 Nixon (1995)
# Clickstream Status:  True
# Streaming event:  10 Boys Life (1995)
# Clickstream Status:  True
# Streaming event:  10 Age of Innocence, The (1993)
# Clickstream Status:  True
# Streaming event:  10 Mary Shelley's Frankenstein (1994)
# Clickstream Status:  True
# Streaming event:  10 Funny Face (1957)
# Clickstream Status:  True
# Streaming event:  10 Room with a View, A (1986)
# Clickstream Status:  True
# Streaming event:  10 Denise Calls Up (1995)
# Clickstream Status:  True
# Streaming event:  10 Love! Valour! Compassion! (1997)
# Clickstream Status:  True
# Streaming event:  10 Nina Takes a Lover (1994)
# Clickstream Status:  True
# Streaming event:  10 L.A. Confidential (1997)
# Clickstream Status:  True
# Streaming event:  10 Sting, The (1973)
# Clickstream Status:  True
# Streaming event:  10 Babe (1995)
# Clickstream Status:  True
# Streaming event:  10 Searching for Bobby Fischer (1993)
# Clickstream Status:  True
# Streaming event:  10 Marlene Dietrich: Shadow and Light (1996)
# Clickstream Status:  True
# Streaming event:  10 Last Dance (1996)
# Clickstream Status:  True
# Streaming event:  10 Shadow of Angels (Schatten der Engel) (1976)
# Clickstream Status:  True
# Streaming event:  10 Mark of Zorro, The (1940)
# Clickstream Status:  True
# Streaming event:  10 B. Monkey (1998)
# Clickstream Status:  True
# Streaming event:  10 Portrait of a Lady, The (1996)
# Clickstream Status:  True
# Streaming event:  10 Lassie (1994)
# Clickstream Status:  True
# Streaming event:  10 For Ever Mozart (1996)
# Clickstream Status:  True
# Streaming event:  10 Heaven & Earth (1993)
# Clickstream Status:  True
# Streaming event:  10 Harriet the Spy (1996)
# Clickstream Status:  True
# Streaming event:  10 The Innocent (1994)
# Clickstream Status:  True
# Streaming event:  10 Gay Divorcee, The (1934)
# Clickstream Status:  True
# Streaming event:  10 Ghost and the Darkness, The (1996)
# Clickstream Status:  True
# Streaming event:  10 Careful (1992)
# Clickstream Status:  True
# Streaming event:  10 Bulletproof (1996)
# Clickstream Status:  True
# Streaming event:  10 Lost in Space (1998)
# Clickstream Status:  True
# Streaming event:  10 Wonderland (1997)
# Clickstream Status:  True
# Streaming event:  10 Close Shave, A (1995)
# Clickstream Status:  True
# Streaming event:  10 Roommates (1995)
# Clickstream Status:  True
# Streaming event:  10 Specialist, The (1994)
# Clickstream Status:  True
# Streaming event:  10 Glory (1989)
# Clickstream Status:  True
# Streaming event:  10 Magic Hour, The (1998)
# Clickstream Status:  True
# Streaming event:  10 Firm, The (1993)
# Clickstream Status:  True
# Streaming event:  10 Death in Brunswick (1991)
# Clickstream Status:  True
# Streaming event:  10 American Dream (1990)
# Clickstream Status:  True
# Streaming event:  10 Batman Returns (1992)
# Clickstream Status:  True
# Streaming event:  10 Some Kind of Wonderful (1987)
# Clickstream Status:  True
# Streaming event:  10 Invitation, The (Zaproszenie) (1986)
# Clickstream Status:  True
# Streaming event:  10 Bewegte Mann, Der (1994)
# Clickstream Status:  True
# Streaming event:  10 Vampire in Brooklyn (1995)
# Clickstream Status:  True
# Streaming event:  10 Letter From Death Row, A (1998)
# Clickstream Status:  True
# Streaming event:  10 Fathers' Day (1997)
# Clickstream Status:  True
# Streaming event:  10 Things to Do in Denver when You're Dead (1995)
# Clickstream Status:  True
# Streaming event:  10 Boy's Life 2 (1997)
# Clickstream Status:  True
# Streaming event:  10 Blown Away (1994)
# Clickstream Status:  True
# Streaming event:  10 Salut cousin! (1996)
# Clickstream Status:  True
# Streaming event:  10 Mr. Magoo (1997)
# Clickstream Status:  True
# Streaming event:  10 Ladybird Ladybird (1994)
# Clickstream Status:  True
# Streaming event:  10 Corrina, Corrina (1994)
# Clickstream Status:  True
# Streaming event:  10 Bloodsport 2 (1995)
# Clickstream Status:  True
# Streaming event:  10 Anaconda (1997)
# Clickstream Status:  True
# Streaming event:  10 Last Dance (1996)
# Clickstream Status:  True
# Streaming event:  10 Exit to Eden (1994)
# Clickstream Status:  True
# Streaming event:  10 Heavenly Creatures (1994)
# Clickstream Status:  True
# Streaming event:  10 Raising Arizona (1987)
# Clickstream Status:  True
# Streaming event:  10 If Lucy Fell (1996)
# Clickstream Status:  True
# Streaming event:  10 Backbeat (1993)

# %% [markdown]
# ## Generating the Solution:
#
# Just like in your original setup notebook the following cells could take a little time to run, be patient and they should be complete in 30-40 minutes.

# %%
recipe_list = [
    "arn:aws:personalize:::recipe/awspersonalizehrnnmodel",
    "arn:aws:personalize:::recipe/awspersonalizedeepfmmodel",
    "arn:aws:personalize:::recipe/awspersonalizesimsmodel",
    "arn:aws:personalize:::recipe/awspersonalizeffnnmodel",
    "arn:aws:personalize:::recipe/popularity-baseline"
]

recipe_arn = recipe_list[0]

create_solution_response = personalize.create_solution(
    name = "Dj-movielens-clickst",
    datasetGroupArn = datasetGroupArn,
    recipeArn = recipe_arn,
    minProvisionedTPS = 1
)

solution_arn = create_solution_response['solutionArn']
print(json.dumps(create_solution_response, indent=2))
# Out:
# {
#   "solutionArn": "arn:aws:personalize:us-east-1:059124553121:solution/Dj-movielens-clickst",
#   "ResponseMetadata": {
#     "RequestId": "ee1da46c-4882-4089-9959-f99d4605d260",
#     "HTTPStatusCode": 200,
#     "HTTPHeaders": {
#       "content-type": "application/x-amz-json-1.1",
#       "date": "Fri, 15 Feb 2019 20:17:58 GMT",
#       "x-amzn-requestid": "ee1da46c-4882-4089-9959-f99d4605d260",
#       "content-length": "90",
#       "connection": "keep-alive"
#     },
#     "RetryAttempts": 0
#   }
# }

# %%
status = None
max_time = time.time() + 3*60*60 # 3 hours
while time.time() < max_time:
    describe_solution_response = personalize.describe_solution(
        solutionArn = solution_arn
    )
    status = describe_solution_response["solution"]["status"]
    print("Solution: {}".format(status))
    
    if status == "ACTIVE" or status == "CREATE FAILED":
        break
        
    time.sleep(60)
# Out:
# Solution: CREATE PENDING
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: CREATE IN_PROGRESS
# Solution: ACTIVE

# %% [markdown]
# ## Create and Wait for Campaign

# %%
create_campaign_response = personalize.create_campaign(
    name = "Dj-click-campaign",
    solutionArn = solution_arn,
    updateMode = "MANUAL"
)

campaign_arn = create_campaign_response['campaignArn']
print(json.dumps(create_campaign_response, indent=2))
# Out:
# {
#   "campaignArn": "arn:aws:personalize:us-east-1:059124553121:campaign/Dj-click-campaign",
#   "ResponseMetadata": {
#     "RequestId": "6f3941cf-9693-4d31-b87b-e1c074eed6eb",
#     "HTTPStatusCode": 200,
#     "HTTPHeaders": {
#       "content-type": "application/x-amz-json-1.1",
#       "date": "Fri, 15 Feb 2019 21:24:23 GMT",
#       "x-amzn-requestid": "6f3941cf-9693-4d31-b87b-e1c074eed6eb",
#       "content-length": "87",
#       "connection": "keep-alive"
#     },
#     "RetryAttempts": 0
#   }
# }

# %%
status = None
max_time = time.time() + 3*60*60 # 3 hours
while time.time() < max_time:
    describe_campaign_response = personalize.describe_campaign(
        campaignArn = campaign_arn
    )
    status = describe_campaign_response["campaign"]["status"]
    print("Campaign: {}".format(status))
    
    if status == "ACTIVE" or status == "CREATE FAILED":
        break
        
    time.sleep(60)
# Out:
# Campaign: CREATE PENDING
# Campaign: CREATE IN_PROGRESS
# Campaign: CREATE IN_PROGRESS
# Campaign: CREATE IN_PROGRESS
# Campaign: CREATE IN_PROGRESS
# Campaign: CREATE IN_PROGRESS
# Campaign: CREATE IN_PROGRESS
# Campaign: CREATE IN_PROGRESS
# Campaign: ACTIVE

# %% [markdown]
# ## Exporting to the Application
#
# Now that you have a new campaign ARN, you will want to update it in your settings.py file as well. After updating, simply refresh the page and you will be getting recommendations using the new solution.
