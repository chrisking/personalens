# %%
# Setup
from IPython.display import Image
from IPython.core.display import HTML

# %%
# Imports
import django
django.setup()
import pandas as pd
from movielens.models import Item
import requests

# %%
movie_id = 72
movie = Item.objects.get(movie_id=movie_id)
print(movie)
# Out:
# Mask, The (1994)

# %%
POSTER_LOCATION = "/Users/chris/projects/personalens/data/ml-100k/movie_poster.csv"

def get_poster_df():
    """
    This returns a dataframe of movie posters in order to render them in a template
    :return: df of movie posters
    """
    posters = pd.read_csv(POSTER_LOCATION, header=None ,names=['index', 'url'])
    return posters

# %%
posters = get_poster_df()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-123-40b5a852ec5d> in <module>
# ----> 1 posters = get_poster_df()
#
# <ipython-input-122-c38517a2ca76> in get_poster_df()
#       7     :return: df of movie posters
#       8     """
# ----> 9     posters = pd.read_csv(POSTER_LOCATION, header=None ,names=['index', 'url'])
#      10     return posters
#
# ...

# %%
posters.head()
# Out:
#    index                                                url
# 0      1  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 1      2  https://m.media-amazon.com/images/M/MV5BMzk2OT...
# 2      3  https://m.media-amazon.com/images/M/MV5BNDc3Y2...
# 3      4  https://m.media-amazon.com/images/M/MV5BMjAwOD...
# 4      5  https://m.media-amazon.com/images/M/MV5BYWUwND...

# %%
posters.loc[movie_id]['url']
# Out:
# 'https://m.media-amazon.com/images/M/MV5BNDA2MTYyNDE4NV5BMl5BanBnXkFtZTcwOTY5ODA3NA@@..jpg'

# %%
movie.movie_title
# Out:
# 'Mask, The (1994)'

# %%
url = posters.loc[movie.movie_id]['url']
resp = requests.get(url)

# %%
Image(resp.content)
